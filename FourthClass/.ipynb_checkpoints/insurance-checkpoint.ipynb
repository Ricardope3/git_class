# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ins = pd.read_csv("insurance.csv")

# %%
ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Which sex is charged the highest?
gp = ins.groupby('sex')
gp.sum()['charges'].idxmax()
# Out:
# 'male'

# %%
#Which region has the most amount of smokers?
ins['smoker'] = ins['smoker'] == "yes"
ins.head()
# region = ins.groupby("region")
# region.sum()
# ins.pivot_table(index='region', aggfunc='sum')['smoker'].idxmax()
# Out:
#    age     sex     bmi  children  smoker     region      charges
# 0   19  female  27.900         0    True  southwest  16884.92400
# 1   18    male  33.770         1   False  southeast   1725.55230
# 2   28    male  33.000         3   False  southeast   4449.46200
# 3   33    male  22.705         0   False  northwest  21984.47061
# 4   32    male  28.880         0   False  northwest   3866.85520

# %%
#Who is getting charged 3 standard deviatons more than the others in their age group?
for age in ins['age'].unique():
    print(age, (ins['age'] == age).sum())
# Out:
# 19 68
# 18 69
# 28 28
# 33 26
# 32 26
# 31 27
# 46 29
# 37 25
# 60 23
# 25 28
# 62 23
# 23 28
# 56 26
# 27 28
# 52 29
# 30 27
# 34 26
# 59 25
# 63 23
# 55 26
# 22 28
# 26 28
# 35 25
# 24 28
# 41 27
# 38 25
# 36 25
# 21 28
# 48 29
# 40 27
# 58 25
# 53 28
# 43 27
# 64 22
# 20 29
# 61 23
# 44 27
# 57 26
# 29 27
# 45 29
# 54 28
# 49 28
# 47 29
# 51 29
# 42 27
# 50 29
# 39 25

# %%
mean_charges = ins.groupby('age').mean()['charges']
std_charges = ins.groupby('age').std()['charges']

# %%
for index, row in ins.iterrows():
#     print(mean_charges[row['age']])
    ins.iloc(index) = mean_charges[row['age']]
ins
# Out:
#   Input In [67]
#     ins.iloc(index) = mean_charges[row['age']]
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
i = 0 
for i in ins.index :
    print(ins.iloc[i,0])
# Out:
# 19
# 18
# 28
# 33
# 32
# 31
# 46
# 37
# 37
# 60
# 25
# 62
# 23
# 56
# 27
# 19
# 52
# 23
# 56
# 30
# 60
# 30
# 18
# 34
# 37
# 59
# 63
# 55
# 23
# 31
# 22
# 18
# 19
# 63
# 28
# 19
# 62
# 26
# 35
# 60
# 24
# 31
# 41
# 37
# 38
# 55
# 18
# 28
# 60
# 36
# 18
# 21
# 48
# 36
# 40
# 58
# 58
# 18
# 53
# 34
# 43
# 25
# 64
# 28
# 20
# 19
# 61
# 40
# 40
# 28
# 27
# 31
# 53
# 58
# 44
# 57
# 29
# 21
# 22
# 41
# 31
# 45
# 22
# 48
# 37
# 45
# 57
# 56
# 46
# 55
# 21
# 53
# 59
# 35
# 64
# 28
# 54
# 55
# 56
# 38
# 41
# 30
# 18
# 61
# 34
# 20
# 19
# 26
# 29
# 63
# 54
# 55
# 37
# 21
# 52
# 60
# 58
# 29
# 49
# 37
# 44
# 18
# 20
# 44
# 47
# 26
# 19
# 52
# 32
# 38
# 59
# 61
# 53
# 19
# 20
# 22
# 19
# 22
# 54
# 22
# 34
# 26
# 34
# 29
# 30
# 29
# 46
# 51
# 53
# 19
# 35
# 48
# 32
# 42
# 40
# 44
# 48
# 18
# 30
# 50
# 42
# 18
# 54
# 32
# 37
# 47
# 20
# 32
# 19
# 27
# 63
# 49
# 18
# 35
# 24
# 63
# 38
# 54
# 46
# 41
# 58
# 18
# 22
# 44
# 44
# 36
# 26
# 30
# 41
# 29
# 61
# 36
# 25
# 56
# 18
# 19
# 39
# 45
# 51
# 64
# ...

# %%
ins[ins.pipe(lambda x: (x['charges']-x['mean_charges'])/x['std_charges']) > 3]
# Out:
#       age     sex     bmi  children  smoker     region      charges  \
# 34     28    male  36.400         1    True  southwest  51194.55914
# 55     58    male  36.955         2    True  northwest  47496.49445
# 256    56    male  33.630         0    True  northwest  43921.18370
# 373    26    male  32.900         2    True  southwest  36085.21900
# 530    57    male  42.130         1    True  southeast  48675.51770
# 543    54  female  47.410         0    True  southeast  63770.42801
# 569    48    male  40.565         2    True  northwest  45702.02235
# 577    31  female  38.095         1    True  northeast  58571.07448
# 682    39    male  35.300         2    True  southwest  40103.89000
# 697    41    male  35.750         1    True  southeast  40273.64550
# 739    29    male  35.500         2    True  southwest  44585.45587
# 803    18  female  42.240         0    True  southeast  38792.68560
# 819    33  female  35.530         0    True  northwest  55135.40209
# ...

# %%
for index, row in ins.iterrows():
    if ((row['charges']-row['mean_charges'])/row['std_charges'] > 3) and index:
        print(ins.iloc[index])
# Out:
# age                   28
# sex                 male
# bmi                 36.4
# children               1
# smoker              True
#                 ...
# 1333        15663.003301
# 1334         7086.217556
# 1335         7086.217556
# 1336          4730.46433
# 1337        22024.457609
# Name: 34, Length: 1348, dtype: object
# age                   58
# sex                 male
# bmi               36.955
# children               2
# smoker              True
#                 ...
# 1333        15663.003301
# 1334         7086.217556
# 1335         7086.217556
# 1336          4730.46433
# 1337        22024.457609
# Name: 55, Length: 1348, dtype: object
# age                   56
# sex                 male
# bmi                33.63
# children               0
# smoker              True
#                 ...
# 1333        15663.003301
# 1334         7086.217556
# 1335         7086.217556
# 1336          4730.46433
# 1337        22024.457609
# Name: 256, Length: 1348, dtype: object
# ...

# %%
ins.query("charges > 3")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [60], in <module>
# ----> 1 ins.query("charges.isNan()")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4105, in DataFrame.query(self, expr, inplace, **kwargs)
#    4103 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4104 kwargs["target"] = None
# -> 4105 res = self.eval(expr, **kwargs)
#    4107 try:
#    4108     result = self.loc[res]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4234, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4231     kwargs["target"] = self
#    4232 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4234 return _eval(expr, inplace=inplace, **kwargs)
#
# ...

# %%
ins[ins['charges' ] > 3]
# Out:
#       age     sex     bmi  children  smoker     region      charges  \
# 0      19  female  27.900         0    True  southwest  16884.92400
# 1      18    male  33.770         1   False  southeast   1725.55230
# 2      28    male  33.000         3   False  southeast   4449.46200
# 3      33    male  22.705         0   False  northwest  21984.47061
# 4      32    male  28.880         0   False  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50    male  30.970         3   False  northwest  10600.54830
# 1334   18  female  31.920         0   False  northeast   2205.98080
# 1335   18  female  36.850         0   False  southeast   1629.83350
# 1336   21  female  25.800         0   False  southwest   2007.94500
# 1337   61  female  29.070         0    True  northwest  29141.36030
#
#       mean_charges   std_charges  prueba
# 0      9747.909335  12469.537468     NaN
# 1      7086.217556  10198.459989     NaN
# ...

# %%
ins['mean_charges']
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 1333    None
# 1334    None
# 1335    None
# 1336    None
# 1337    None
# Name: mean_charges, Length: 1338, dtype: object

# %%
ins.size
# Out:
# 12042

# %%
ins_pivot = ins.pivot_table(index=["region"], columns=["sex"],aggfunc='sum', values=['bmi','charges'])
ins_pivot
# Out:
#                 bmi                 charges
# sex          female      male        female          male
# region
# northeast  4721.215  4731.000  2.085466e+06  2.258203e+06
# northwest  4801.585  4688.345  2.046699e+06  1.989013e+06
# southeast  5717.470  6424.110  2.362442e+06  3.001248e+06
# southwest  4869.800  5074.100  1.826455e+06  2.186300e+06

# %%
ins_pivot = ins.pivot_table(index=["children"],aggfunc='mean', )
ins_pivot
# Out:
#                 age        bmi       charges
# children
# 0         38.444251  30.550296  12365.975602
# 1         39.453704  30.623148  12731.171832
# 2         39.445833  30.978104  15073.563734
# 3         41.566879  30.684331  15355.318367
# 4         39.000000  31.391200  13850.656311
# 5         35.611111  29.605000   8786.035247

# %%
# Out:
# 'male'

# %%
ins['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
region_data = sns.load_dataset("iris")

# %%
x = ins['age']
y = ins['charges']

plt.figure(figsize=(16,7))
sns.scatterplot(x='x',y='y',hue='target',palette=sns.color_palette("hls",10),data=df,
               legend="full")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
# ----> 1 x = ins['age']
#       2 y = ins['charges']
#       4 plt.figure(figsize=(16,7))
#
# NameError: name 'ins' is not defined

# %%
ins
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
ins['Range 0 - 200'] =
