# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
co = pd.to_csv(json_file)

# %%
co.head()
co.query('')

# id name semester courses_table_id
 a01229141   'marcia' 2  141
    
# course_id student_id 
   isc-11 a01229141
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
list(co.columns)
# Out:
# ['iso_code',
#  'continent',
#  'location',
#  'date',
#  'total_cases',
#  'new_cases',
#  'new_cases_smoothed',
#  'total_deaths',
#  'new_deaths',
#  'new_deaths_smoothed',
#  'total_cases_per_million',
#  'new_cases_per_million',
#  'new_cases_smoothed_per_million',
#  'total_deaths_per_million',
#  'new_deaths_per_million',
#  'new_deaths_smoothed_per_million',
#  'reproduction_rate',
#  'icu_patients',
#  'icu_patients_per_million',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'weekly_hosp_admissions',
#  'weekly_hosp_admissions_per_million',
#  'new_tests',
#  'total_tests',
#  'total_tests_per_thousand',
#  'new_tests_per_thousand',
#  'new_tests_smoothed',
#  'new_tests_smoothed_per_thousand',
#  'positive_rate',
#  'tests_per_case',
#  'tests_units',
#  'total_vaccinations',
#  'people_vaccinated',
#  'people_fully_vaccinated',
#  'total_boosters',
#  'new_vaccinations',
# ...

# %%
#Total cases in each country

# %%
[co[co['iso_code'] == country].iloc[-1]['total_cases'] for country in co['iso_code'].unique()]
# Out:
# [174331.0,
#  11268386.0,
#  272030.0,
#  265227.0,
#  38434.0,
#  98796.0,
#  2555.0,
#  7455.0,
#  8934328.0,
#  421226.0,
#  33732.0,
#  120758420.0,
#  3362035.0,
#  2839297.0,
#  788958.0,
#  33169.0,
#  525171.0,
#  1946737.0,
#  56013.0,
#  929340.0,
#  3586292.0,
#  56876.0,
#  26575.0,
#  11634.0,
#  14451.0,
#  894551.0,
#  7616.0,
#  372139.0,
#  263950.0,
#  29040800.0,
#  6091.0,
#  84844.0,
#  1100811.0,
#  20751.0,
#  38150.0,
#  132072.0,
#  119322.0,
#  3334009.0,
#  55892.0,
#  19373.0,
#  14320.0,
#  7257.0,
#  3168335.0,
#  110868.0,
#  6070616.0,
#  8047.0,
#  24020.0,
#  2.0,
#  814583.0,
#  81546.0,
#  1062953.0,
#  1072474.0,
#  39133.0,
#  331508.0,
#  3624937.0,
#  86154.0,
#  2853236.0,
#  15550.0,
#  11248.0,
#  575883.0,
#  836216.0,
#  489876.0,
#  156364.0,
#  15889.0,
#  9715.0,
#  514067.0,
#  69297.0,
#  468930.0,
#  161250662.0,
#  111173878.0,
#  34658.0,
#  115.0,
#  64019.0,
#  671773.0,
#  23064766.0,
#  68425.0,
#  47559.0,
#  11948.0,
# ...

# %%
co[co['iso_code'] == 'AMB']
# Out:
# Empty DataFrame
# ...

# %%
[co[co['iso_code'] == country].iloc[-1]['total_cases'] for country in co['iso_code'].unique()]
# Out:
# [174331.0,
#  11268386.0,
#  272030.0,
#  265227.0,
#  38434.0,
#  98796.0,
#  2555.0,
#  7455.0,
#  8934328.0,
#  421226.0,
#  33732.0,
#  120758420.0,
#  3362035.0,
#  2839297.0,
#  788958.0,
#  33169.0,
#  525171.0,
#  1946737.0,
#  56013.0,
#  929340.0,
#  3586292.0,
#  56876.0,
#  26575.0,
#  11634.0,
#  14451.0,
#  894551.0,
#  7616.0,
#  372139.0,
#  263950.0,
#  29040800.0,
#  6091.0,
#  84844.0,
#  1100811.0,
#  20751.0,
#  38150.0,
#  132072.0,
#  119322.0,
#  3334009.0,
#  55892.0,
#  19373.0,
#  14320.0,
#  7257.0,
#  3168335.0,
#  110868.0,
#  6070616.0,
#  8047.0,
#  24020.0,
#  2.0,
#  814583.0,
#  81546.0,
#  1062953.0,
#  1072474.0,
#  39133.0,
#  331508.0,
#  3624937.0,
#  86154.0,
#  2853236.0,
#  15550.0,
#  11248.0,
#  575883.0,
#  836216.0,
#  489876.0,
#  156364.0,
#  15889.0,
#  9715.0,
#  514067.0,
#  69297.0,
#  468930.0,
#  161250662.0,
#  111173878.0,
#  34658.0,
#  115.0,
#  64019.0,
#  671773.0,
#  23064766.0,
#  68425.0,
#  47559.0,
#  11948.0,
# ...

# %%
for country in co['iso_code'].unique():
    print(co[co['iso_code'] == country])
# Out:
#     iso_code continent     location        date  total_cases  new_cases  \
# 0        AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1        AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2        AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3        AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4        AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ..       ...       ...          ...         ...          ...        ...
# 736      AFG      Asia  Afghanistan  2022-03-01     173879.0      220.0
# 737      AFG      Asia  Afghanistan  2022-03-02     174073.0      194.0
# 738      AFG      Asia  Afghanistan  2022-03-03     174214.0      141.0
# 739      AFG      Asia  Afghanistan  2022-03-04     174214.0        0.0
# 740      AFG      Asia  Afghanistan  2022-03-05     174331.0      117.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
[co[co['iso_code'] == country]['new_cases'].sum() for country in co['iso_code'].unique()]
# Out:
# [174339.0,
#  11254551.0,
#  272030.0,
#  265227.0,
#  38434.0,
#  98796.0,
#  2555.0,
#  7457.0,
#  8934328.0,
#  421226.0,
#  33732.0,
#  119995444.0,
#  3391465.0,
#  2839297.0,
#  788958.0,
#  33217.0,
#  525171.0,
#  1946737.0,
#  56013.0,
#  929340.0,
#  3586292.0,
#  56876.0,
#  26784.0,
#  11634.0,
#  14451.0,
#  894551.0,
#  7616.0,
#  372139.0,
#  263950.0,
#  28935718.0,
#  6091.0,
#  84862.0,
#  1100811.0,
#  20751.0,
#  38150.0,
#  132072.0,
#  119322.0,
#  3334009.0,
#  55892.0,
#  19373.0,
#  14320.0,
#  7257.0,
#  3168335.0,
#  110327.0,
#  6070616.0,
#  8047.0,
#  24020.0,
#  2.0,
#  814583.0,
#  85564.0,
#  1062953.0,
#  1072474.0,
#  39133.0,
#  331508.0,
#  3628247.0,
#  86154.0,
#  2855237.0,
#  15550.0,
#  11282.0,
#  575883.0,
#  847689.0,
#  489876.0,
#  156456.0,
#  15889.0,
#  9715.0,
#  514067.0,
#  69297.0,
#  468930.0,
#  160935382.0,
#  111699017.0,
#  34658.0,
#  117.0,
#  64019.0,
#  671773.0,
#  23488526.0,
#  68434.0,
#  47559.0,
#  12048.0,
# ...

# %%
co.pivot_table(index='iso_code', aggfunc='sum')['new_cases']
# Out:
# iso_code
# ABW      33732.0
# AFG     174339.0
# AGO      98796.0
# AIA       2555.0
# ALB     272030.0
#          ...
# WSM         33.0
# YEM      11776.0
# ZAF    3664586.0
# ZMB     313744.0
# ZWE     239025.0
# Name: new_cases, Length: 238, dtype: float64

# %%
co.groupby('iso_code').sum()['new_cases']
# Out:
# iso_code
# ABW      33732.0
# AFG     174339.0
# AGO      98796.0
# AIA       2555.0
# ALB     272030.0
#          ...
# WSM         33.0
# YEM      11776.0
# ZAF    3664586.0
# ZMB     313744.0
# ZWE     239025.0
# Name: new_cases, Length: 238, dtype: float64

# %%
co['total_country_cases'] = co.groupby('iso_code')['new_cases'].transform(lambda x: x.sum())

# %%
co['total_vaccinations_per_million_country'] = co['total_vaccinations_per_hundred_country']*10000
co.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_vaccinations_per_hundred_country'
#
# ...

# %%
co[['total_country_vaccinations', 'total_cases_per_million_country','total_vaccinations_per_hundred_country']].corr()
# Out:
#                                         total_country_vaccinations  \
# total_country_vaccinations                                1.000000
# total_cases_per_million_country                          -0.079175
# total_vaccinations_per_hundred_country                    0.091771
#
#                                         total_cases_per_million_country  \
# total_country_vaccinations                                    -0.079175
# total_cases_per_million_country                                1.000000
# total_vaccinations_per_hundred_country                         0.564433
#
#                                         total_vaccinations_per_hundred_country
# total_country_vaccinations                                            0.091771
# total_cases_per_million_country                                       0.564433
# total_vaccinations_per_hundred_country                                1.000000

# %%
co['total_country_vaccinations'] = co.groupby('iso_code')['new_vaccinations'].transform(lambda x: x.sum())
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 166321      ZWE    Africa     Zimbabwe  2022-03-01     236871.0      491.0
# 166322      ZWE    Africa     Zimbabwe  2022-03-02     237503.0      632.0
# 166323      ZWE    Africa     Zimbabwe  2022-03-03     237503.0        0.0
# 166324      ZWE    Africa     Zimbabwe  2022-03-04     238739.0     1236.0
# 166325      ZWE    Africa     Zimbabwe  2022-03-05     239019.0      280.0
#
# ...

# %%
co['total_cases_per_million_country'] = co.groupby('iso_code')['total_cases_per_million'].transform(lambda x: x.max())
co['total_vaccinations_per_hundred_country'] = co.groupby('iso_code')['total_vaccinations_per_hundred'].transform(lambda x: x.max())

# %%
co.groupby('iso_code')['total_vaccinations_per_hundred'].transform(lambda x: x.max())
co.groupby('iso_code').sum()['total_vaccinations_per_hundred']

# %%
co['total_vaccinations_per_million_country'] = co['total_vaccinations_per_hundred_country']*10000
co.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    life_expectancy  human_development_index  \
# 0            64.83                    0.511
# ...

# %%
co[['total_cases_per_million_country','total_vaccinations_per_million_country']].corr()
# Out:
#                                         total_cases_per_million_country  \
# total_cases_per_million_country                                1.000000
# total_vaccinations_per_million_country                         0.564433
#
#                                         total_vaccinations_per_million_country
# total_cases_per_million_country                                       0.564433
# total_vaccinations_per_million_country                                1.000000
