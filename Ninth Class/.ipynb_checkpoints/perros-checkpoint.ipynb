# %%
import pandas as pd
from bokeh.io import output_notebook
output_notebook()
bokeh_width, bokeh_height = 500,400
import os
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
api_key = "AIzaSyC_8QhTAOkJO5MpOIDbqlEvk4wFjYd4myQ"

# %%
lat, lon = 46.2437, 6.0251

# %%
from bokeh.io import show
from bokeh.plotting import gmap
from bokeh.models import GMapOptions

def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='Pays de Gex', 
             width=bokeh_width, height=bokeh_height)
    show(p)
    return p

# %%
p = plot(lat, lon)
# Out:
#   <div class="bk-root" id="0f309513-ec0d-44ed-9e27-e14100347603" data-root-id="1004"></div>

# %%
os. getcwd()
# Out:
# 'C:\\Users\\ricardoesp\\OneDrive - Microsoft\\Desktop\\DS\\Ninth Class'

# %%
perro = pd.read_csv('perros.csv')

# %%
perro.head()
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 3   A665644      NaN  10/21/2013 07:59:00 AM  10/21/2013 07:59:00 AM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
perro['loc'] = perro['Found Location']

# %%
perro[perro['loc'] == 'Austin (TX)'].count()
# Out:
# Animal ID           22859
# Name                20003
# DateTime            22859
# MonthYear           22859
# Found Location      22859
# Intake Type         22859
# Intake Condition    22859
# Animal Type         22859
# Sex upon Intake     22859
# Age upon Intake     22859
# Breed               22859
# Color               22859
# loc                 22859
# dtype: int64

# %%
perro[perro['loc'] != 'Austin (TX)'].count()
# Out:
# Animal ID           101261
# Name                 65066
# DateTime            101261
# MonthYear           101261
# Found Location      101261
# Intake Type         101261
# Intake Condition    101261
# Animal Type         101261
# Sex upon Intake     101260
# Age upon Intake     101261
# Breed               101261
# Color               101261
# loc                 101261
# dtype: int64

# %%
perro = perro[perro['loc'] != 'Austin (TX)']
perro.head()
# Out:
#   Animal ID     Name                DateTime               MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  01/03/2019 04:19:00 PM
# 1   A706918    Belle  07/05/2015 12:59:00 PM  07/05/2015 12:59:00 PM
# 2   A724273  Runster  04/14/2016 06:43:00 PM  04/14/2016 06:43:00 PM
# 4   A682524      Rio  06/29/2014 10:38:00 AM  06/29/2014 10:38:00 AM
# 6   A635072  Beowulf  04/16/2019 09:53:00 AM  04/16/2019 09:53:00 AM
#
#                         Found Location    Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)          Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)          Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)          Stray           Normal
# 4        800 Grove Blvd in Austin (TX)          Stray           Normal
# 6  415 East Mary Street in Austin (TX)  Public Assist           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 4         Dog   Neutered Male         4 years
# 6         Dog   Neutered Male         6 years
#
#                                    Breed        Color  \
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray
# 6                         Great Dane Mix        Black
#
#                                    loc
# 0  2501 Magin Meadow Dr in Austin (TX)
# 1     9409 Bluegrass Dr in Austin (TX)
# 2   2818 Palomino Trail in Austin (TX)
# 4        800 Grove Blvd in Austin (TX)
# 6  415 East Mary Street in Austin (TX)

# %%
from geopy.geocoders import GoogleV3
import geopy.distance
import googlemaps
from geopy.geocoders import Nominatim

# %%
geolocator = GoogleV3(api_key=api_key)
name = '2501 Magin Meadow Dr in Austin (TX)'
location = geolocator.geocode(name)
location
# Out:
# Location(2501 Magin Meadow Dr, Austin, TX 78744, USA, (30.179535, -97.76176749999999, 0.0))

# %%
add_dict = location.raw
print(add_dict)
# Out:
# {'address_components': [{'long_name': '2501', 'short_name': '2501', 'types': ['street_number']}, {'long_name': 'Magin Meadow Drive', 'short_name': 'Magin Meadow Dr', 'types': ['route']}, {'long_name': 'Meadows Lake', 'short_name': 'Meadows Lake', 'types': ['neighborhood', 'political']}, {'long_name': 'Austin', 'short_name': 'Austin', 'types': ['locality', 'political']}, {'long_name': 'Travis County', 'short_name': 'Travis County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Texas', 'short_name': 'TX', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '78744', 'short_name': '78744', 'types': ['postal_code']}, {'long_name': '5220', 'short_name': '5220', 'types': ['postal_code_suffix']}], 'formatted_address': '2501 Magin Meadow Dr, Austin, TX 78744, USA', 'geometry': {'bounds': {'northeast': {'lat': 30.1795867, 'lng': -97.76169759999999}, 'southwest': {'lat': 30.179465, 'lng': -97.7618147}}, 'location': {'lat': 30.179535, 'lng': -97.76176749999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 30.1809361802915, 'lng': -97.76040716970849}, 'southwest': {'lat': 30.1782382197085, 'lng': -97.76310513029149}}}, 'place_id': 'ChIJdSpmoxWzRIYRX1fPgZTfp0A', 'types': ['premise']}

# %%
print(add_dict.keys())
# Out:
# dict_keys(['address_components', 'formatted_address', 'geometry', 'place_id', 'types'])

# %%
coordinates = add_dict["geometry"]["location"]
print(coordinates)
print(add_dict["geometry"]["location"]["lat"])
# Out:
# {'lat': 30.179535, 'lng': -97.76176749999999}
# 30.179535

# %%
#geolocator = GoogleV3(api_key=api_key)
#name = '2501 Magin Meadow Dr in Austin (TX)'
#location = geolocator.geocode(name)
#location

# %%
def coordinates(address):
    name = address
    location = geolocator.geocode(name)
    components = location.raw
    lat = add_dict["geometry"]["location"]["lat"]
    lon = add_dict["geometry"]["location"]["lng"]
